# %%
import feedparser
import requests
import re

# %%
url = "https://www.cert.ssi.gouv.fr/alerte/feed/"
rss_alertes_feed = feedparser.parse(url)
for entry in rss_alertes_feed.entries:
 print("Titre :", entry.title)
 print("Description:", entry.description)
 print("Lien :", entry.link)
 print("Date :", entry.published)
# Out:
# Titre : Multiples vulnérabilités dans AMI MegaRAC (16 décembre 2022)
# Description: Le 05 décembre 2022, trois vulnérabilités respectivement identifiées par les numéros CVE-2022-40259, CVE-2022-40242 et CVE-2022-2827 ont été signalées dans la solution d’administration à distance MegaRAC de l’éditeur AMI. La solution MegaRAC s’appuie sur un BMC (Baseboard Management Controller) :...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2022-ALE-014/
# Date : Fri, 16 Dec 2022 00:00:00 +0000
# Titre : Vulnérabilité dans les produits Fortinet (13 juin 2023)
# Description: Le 12 juin 2023, Fortinet a publié un avis de sécurité concernant la vulnérabilité CVE-2023-27997. Celle-ci permet à un attaquant non authentifié d'exécuter du code arbitraire à distance sur des produits Fortinet qui proposent une fonctionnalité de *VPN SSL*. Dans une communication supplémentaire...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-004/
# Date : Tue, 13 Jun 2023 00:00:00 +0000
# Titre : Synthèse sur l'exploitation d'une vulnérabilité dans MOVEit Transfer (05 juillet 2023)
# Description: La découverte d'une vulnérabilité affectant le logiciel MOVEit Transfer de Progress Software, le 31 mai 2023, avait conduit le CERT-FR à publier des éléments d'information dans le bulletin d'actualité CERTFR-2023-ACT-025. L'objet de cette alerte CERTFR-2023-ALE-005 est de faire le point sur...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-005/
# Date : Wed, 05 Jul 2023 00:00:00 +0000
# Titre : Vulnérabilité dans les produits Microsoft (12 juillet 2023)
# Description: Dans le cadre de son *Patch Tuesday*, en date du 11 juillet 2023, Microsoft a indiqué l'existence d'une vulnérabilité référencée CVE-2023-36884 \[1\] au sein de plusieurs versions de Windows et produits Office. Un score CVSSv3 de 8.3 lui a été attribué. L'éditeur confirme qu'elle est activement...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-006/
# Date : Wed, 12 Jul 2023 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans Zimbra Collaboration Suite (17 juillet 2023)
# Description: \[Mise à jour du 26 juillet 2023\] Publication du correctif de sécurité par l'éditeur Le 26 juillet 2023, l'éditeur a publié un correctif de sécurité \[1\] pour cette vulnérabilité immatriculée CVE-2023-37580. Il est donc fortement recommandé de déployer le correctif P41 pour toutes les versions...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-007/
# Date : Mon, 17 Jul 2023 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans Citrix NetScaler ADC et NetScaler Gateway (19 juillet 2023)
# Description: Le 18 juillet 2023, Citrix a publié un avis de sécurité concernant plusieurs vulnérabilités. La plus critique, dont l'identifiant CVE est CVE-2023-3519, permet à un attaquant non authentifié d'exécuter du code arbitraire à distance. L'équipement est vulnérable s'il est configuré en tant que...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-008/
# Date : Wed, 19 Jul 2023 00:00:00 +0000
# Titre : [MàJ] Multiples vulnérabilités dans Ivanti Endpoint Manager Mobile (26 juillet 2023)
# Description: \[Mise à jour du 15 septembre 2023\] Correction de la vulnérabilité CVE-2023-35082 Le 21 août 2023, l'éditeur a publié une mise à jour du bulletin complémentaire de sécurité \[3\] pour annoncer la disponibilité d'un correctif concernant la vulnérabilité CVE-2023-35082. Ce correctif est inclus...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-009/
# Date : Wed, 26 Jul 2023 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Exim (02 octobre 2023)
# Description: Le 27 septembre 2023, Zero Day Initiative (ZDI) a publié six avis de sécurité \[1\] concernant des vulnérabilités de type zéro-jour affectant les versions antérieures à 4.96.1 ou 4.97 de l'agent de transfert de courriels (*Mail Transfer Agent* ou *MTA*) Exim. Le 1er octobre 2023, l'éditeur a...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-010/
# Date : Mon, 02 Oct 2023 00:00:00 +0000
# Titre : [MàJ] Multiples vulnérabilités dans Cisco IOS XE (17 octobre 2023)
# Description: \[Mise à jour du 02 novembre 2023\] La version 17.3.8a est disponible. \[Mise à jour du 31 octobre 2023\] Les détails techniques de la vulnérabilité CVE-2023-20198 sont désormais disponibles publiquement. Cette vulnérabilité était déjà massivement exploitée. Tous les équipements exposant...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-011/
# Date : Tue, 17 Oct 2023 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans Citrix NetScaler ADC et NetScaler Gateway (23 octobre 2023)
# Description: \[Mise à jour du 22 novembre 2023\] L'éditeur a publié un document \[3\] le 20 novembre 2023 listant les différents journaux à analyser ainsi que les éléments à rechercher pour identifier une activité pouvant être liée à une compromission. Par ailleurs, la CISA a publié un avis de sécurité le 21...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-012/
# Date : Mon, 23 Oct 2023 00:00:00 +0000
# Titre : Vulnérabilité dans Apache Struts 2 (13 décembre 2023)
# Description: Le 4 décembre 2023, Apache a publié un avis de sécurité concernant la vulnérabilité critique CVE-2023-50164 concernant le cadriciel Struts 2. Cette vulnérabilité permet à un attaquant non authentifié de téléverser une porte dérobée sur un serveur vulnérable, et ainsi exécuter du code arbitraire à...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2023-ALE-013/
# Date : Wed, 13 Dec 2023 00:00:00 +0000
# Titre : [MàJ] Multiples vulnérabilités dans Ivanti Connect Secure et Policy Secure Gateways (11 janvier 2024)
# Description: [Mise à jour du 4 mars 2024] Ivanti a publié le 29 février des recommandations de résolution pour les Ivanti Connect Secure ou Policy Secure en machine virtuelle [16]. [Mise à jour du 15 février 2024] l'éditeur a publié le 15 février des correctifs pour les versions suivantes, qui n'en...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-001/
# Date : Thu, 11 Jan 2024 00:00:00 +0000
# Titre : [MàJ] Multiples Vulnérabilités dans GitLab (12 janvier 2024)
# Description: \[Mise à jour du 29 janvier 2024\] Le 25 janvier 2024, l'éditeur a publié un avis de sécurité concernant plusieurs vulnérabilités affectant GitLab CE et EE. La vulnérabilité CVE-2024-0402 est considérée critique avec un score CVSSv3 de 9,9. Elle permet à un attaquant authentifié d'écrire des...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-002/
# Date : Fri, 12 Jan 2024 00:00:00 +0000
# Titre : [MàJ] Incident affectant les solutions AnyDesk (05 février 2024)
# Description: \[Mise à jour du 27 février 2024\] Le 29 janvier 2024 l'ANSSI a été alertée par le BSI que l'éditeur AnyDesk Software GmbH a été victime d'une fuite de données. Le code source des applications développées par l'éditeur ainsi que des certificats et clés privées pourraient avoir été dérobés. De...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-003/
# Date : Mon, 05 Feb 2024 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans Fortinet FortiOS (09 février 2024)
# Description: \[Mise à jour du 19 mars 2024\] Le CERT-FR a connaissance de codes d'exploitation publics et de nouvelles tentatives d'exploitation. Le 8 février 2024, Fortinet a publié l'avis de sécurité concernant la vulnérabilité critique CVE-2024-21762 affectant le VPN SSL de FortiOS. Cette vulnérabilité...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-004/
# Date : Fri, 09 Feb 2024 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans Microsoft Outlook (15 février 2024)
# Description: \[Mise à jour du 15 mars 2024\] Ajout de précision concernant les défi-réponses NTLM \[Mise à jour du 22 février 2024\] Ajout de recommandations et de précisions sur le fonctionnement de la vulnérabilité. La vulnérabilité CVE-2024-21413 permet à un attaquant de contourner les mesures de sécurité...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-005/
# Date : Thu, 15 Feb 2024 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans Palo Alto Networks GlobalProtect (12 avril 2024)
# Description: \[Mise à jour du 10 mai 2024\] Le CERT-FR est intervenu pour le traitement d'une compromission par rançongiciel au sein d'une entité française. Dans le cadre de cette attaque, la vulnérabilité a été exploitée pour ensuite réaliser une latéralisation dans le système d'information de la victime et...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-006/
# Date : Fri, 12 Apr 2024 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Cisco (25 avril 2024)
# Description: Le 24 avril 2024, Cisco a publié trois avis de sécurité concernant des vulnérabilités affectant les équipements de sécurité ASA et FTD. Deux d'entre eux concernent les vulnérabilités CVE-2024-20353 et CVE-2024-20359 qui sont activement exploitées dans le cadre d'attaques ciblées. La vulnérabilité...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-007/
# Date : Thu, 25 Apr 2024 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans les produits Check Point  (30 mai 2024)
# Description: [Mise à jour du 31 mai 2024] Des preuves de concept sont désormais disponibles publiquement sur Internet. De plus, l'éditeur indique avoir détecté des tentatives de compromission à partir du 7 avril 2024. **[Publication Initiale]** Une vulnérabilité a été découverte dans les produits Check Point....
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-008/
# Date : Thu, 30 May 2024 00:00:00 +0000
# Titre : Vulnérabilité dans OpenSSH (01 juillet 2024)
# Description: Le 1 juillet 2024, OpenSSH a publié un avis de sécurité concernant la vulnérabilité critique CVE-2024-6387. Cette vulnérabilité permet à un attaquant non authentifié d'exécuter du code arbitraire à distance avec les privilèges *root*. L'éditeur précise que les versions 8.5p1 à 9.7p1 sont...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-009/
# Date : Mon, 01 Jul 2024 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Roundcube (09 août 2024)
# Description: Le 4 août 2024, Roundcube a publié des correctifs concernant les vulnérabilités critiques CVE-2024-42008 et CVE-2024-42009 affectant son serveur de courriel. Ces vulnérabilités permettent des injections de code indirectes à distance (XSS) qui peuvent, par exemple, conduire à la récupération du...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-010/
# Date : Fri, 09 Aug 2024 00:00:00 +0000
# Titre : Vulnérabilité dans SonicWall (10 septembre 2024)
# Description: Le 22 août 2024, Sonicwall a publié un correctif concernant la vulnérabilité critique CVE-2024-40766 affectant les pare-feux Sonicwall génération 5, 6 et 7. Cette vulnérabilité, de type contrôle d'accès défaillant, permet à un attaquant de provoquer un déni de service à distance, une atteinte à...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-011/
# Date : Tue, 10 Sep 2024 00:00:00 +0000
# Titre : [MàJ] Vulnérabilités affectant OpenPrinting CUPS (27 septembre 2024)
# Description: **[Mise à jour du 10 octobre 2024]** Le 28 septembre 2024, Elastic Security Labs a publié des règles de détection au format propriétaire de l'éditeur (cf. section Documentation), qui sont confirmées par les analyses du CERT-FR pour la détection des attaques connues. **[Publication initiale]** De...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-012/
# Date : Fri, 27 Sep 2024 00:00:00 +0000
# Titre : Exploitations de vulnérabilités dans Ivanti Cloud Services Appliance (CSA) (22 octobre 2024)
# Description: Ivanti a publié plusieurs avis de sécurité sur des vulnérabilités affectant CSA qui sont activement exploitées : * le 10 septembre 2024, Ivanti a publié un avis de sécurité concernant la vulnérabilité CVE-2024-8190 qui permet à un attaquant, authentifié en tant qu'administrateur, d'exécuter du...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-013/
# Date : Tue, 22 Oct 2024 00:00:00 +0000
# Titre : [MàJ] Multiples vulnérabilités dans Fortinet FortiManager (23 octobre 2024)
# Description: **[Mise à jour du 14 janvier 2025]** **Publication des correctifs** Le 14 janvier 2025, Fortinet a publié un avis de sécurité relatif à la vulnérabilité CVE-2024-50566 qui correspond à la vulnérabilité de type jour-zéro pour laquelle une preuve de concept a été publiée en novembre 2024. Des...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-014/
# Date : Wed, 23 Oct 2024 00:00:00 +0000
# Titre : [MàJ] Multiples vulnérabilités sur l'interface d'administration des équipements Palo Alto Networks (15 novembre 2024)
# Description: Le 8 novembre 2024, Palo Alto Networks a publié un avis de sécurité relatif à une vulnérabilité critique dans certains pare-feux Palo Alto Networks. Elle permet à un attaquant non authentifié d'exécuter du code arbitraire à distance sur l'interface d'administration des équipements. L'éditeur...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2024-ALE-015/
# Date : Fri, 15 Nov 2024 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans les produits Ivanti (09 janvier 2025)
# Description: Une vulnérabilité jour-zéro de type débordement de pile a été découverte dans Ivanti Connect Secure (ICS), Policy Secure (IPS), Neurons for Zero Trust Access (ZTA) gateways. Cette vulnérabilité, d'identifiant CVE-2025-0282, permet à un attaquant non authentifié de provoquer une exécution de code...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-001/
# Date : Thu, 09 Jan 2025 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans les produits Fortinet (14 janvier 2025)
# Description: \[Mise à jour du 28 janvier 2025\] Une preuve de concept permettant l'exploitation de cette vulnérabilité est disponible publiquement. Le 14 janvier 2025, Fortinet a publié un avis de sécurité concernant la vulnérabilité critique CVE-2024-55591 affectant FortiOS et FortiProxy. Elle permet à un...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-002/
# Date : Tue, 14 Jan 2025 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans les produits Ivanti (03 avril 2025)
# Description: **\[Mise à jour du 11 avril 2025\]** Le CERT-FR a connaissance d'une preuve de concept publique permettant de provoquer une exécution de code arbitraire à distance. **[Mise à jour du 04 avril 2025]** Le CERT-FR a connaissance d'une preuve de concept publique permettant de provoquer un arrêt du...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-003/
# Date : Thu, 03 Apr 2025 00:00:00 +0000
# Titre : Activités de post-exploitation dans Fortinet FortiGate (11 avril 2025)
# Description: Fortinet a publié le 10 avril 2025 un billet de blogue [1] indiquant l'utilisation d'une technique de post-exploitation qui permet une atteinte à la confidentialité des données de l'ensemble du système des équipements Fortigate affectés. Cette technique repose sur l'utilisation d'un lien...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-004/
# Date : Fri, 11 Apr 2025 00:00:00 +0000
# Titre : Vulnérabilité dans SAP NetWeaver (28 avril 2025)
# Description: Le 24 avril 2025, SAP a publié un bulletin de sécurité relatif à la vulnérabilité CVE-2025-31324 qui permet l'exécution de code arbitraire à distance pour un utilisateur non authentifié. Cette vulnérabilité est provoquée par un contournement de la politique de sécurité qui permet de télécharger...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-005/
# Date : Mon, 28 Apr 2025 00:00:00 +0000
# Titre : Vulnérabilité dans les produits Fortinet (13 mai 2025)
# Description: Le 13 mai 2025, Fortinet a publié un avis de sécurité concernant la vulnérabilité CVE-2025-32756. Celle-ci permet à un attaquant non authentifié d'exécuter du code arbitraire à distance. L'éditeur indique que cette vulnérabilité est activement exploitée. Les exploitations constatées jusqu'ici...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-006/
# Date : Tue, 13 May 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Ivanti Endpoint Manager Mobile (EPMM) (14 mai 2025)
# Description: [Mise à jour du 15 mai 2025] Une preuve de concept est publiquement disponible sur Internet. [Publication initiale] Le 13 mai 2025, Ivanti a publié deux avis de sécurité concernant les vulnérabilités CVE-2025-4427 et CVE-2025-4428. L'utilisation combinée de ces deux vulnérabilités permet...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-007/
# Date : Wed, 14 May 2025 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans Roundcube (05 juin 2025)
# Description: [Mise à jour du 06 juin 2025] Une preuve de concept est publiquement disponible. [Publication initiale] Le 01 juin 2025, Roundcube a publié des correctifs concernant une vulnérabilité critique affectant son portail de messagerie ainsi que tous les produits l'incluant (par exemple cPanel et...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-008/
# Date : Thu, 05 Jun 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Citrix NetScaler ADC et NetScaler Gateway (01 juillet 2025)
# Description: **[Mise à jour du 17 juillet 2025]** L'éditeur a publié un lien contenant une méthode d'évaluation permettant d'identifier des tentatives d'exploitation dans les journaux applicatifs et systèmes [12]. **[Mise à jour du 7 juillet 2025]** Le 17 juin 2025, Citrix a publié un bulletin de sécurité...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-009/
# Date : Tue, 01 Jul 2025 00:00:00 +0000
# Titre : [MàJ] Multiples vulnérabilités dans Microsoft SharePoint (21 juillet 2025)
# Description: **[Mise à jour du 23 juillet 2025]** Le 20 juillet 2025, Microsoft a publié des correctifs pour une vulnérabilité de type limitation insuffisante d'un chemin d'accès à un répertoire restreint, aussi appelé *path traversal*, affectant SharePoint Enterprise Server 2016, SharePoint Server 2019 et...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-010/
# Date : Mon, 21 Jul 2025 00:00:00 +0000
# Titre : Incidents de sécurité dans les pare-feux SonicWall (05 août 2025)
# Description: [Mise à jour du 7 août 2025] Le 6 août 2025, SonicWall a remplacé une partie de son communiqué initial pour indiquer que les incidents de sécurité évoqués étaient vraisemblablement corrélés à la vulnérabilité CVE-2024-40766. Celle-ci a fait l'objet d'un bulletin de sécurité, SNWLID-2024-0015 (cf....
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-011/
# Date : Tue, 05 Aug 2025 00:00:00 +0000
# Titre : Vulnérabilité dans Citrix NetScaler ADC et NetScaler Gateway (26 août 2025)
# Description: Le 26 août 2025, Citrix a publié un bulletin de sécurité (cf. section Documentation) concernant, entre autres, la vulnérabilité CVE-2025-7775. Celle-ci permet une exécution de code arbitraire à distance et affecte toutes les versions de Citrix NetScaler ADC et NetScaler Gateway, dans certaines...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-012/
# Date : Tue, 26 Aug 2025 00:00:00 +0000
# Titre : [MàJ] Multiples vulnérabilités dans Cisco ASA et FTD (25 septembre 2025)
# Description: **[Mise à jour du 07 novembre 2025]** Le 5 novembre 2025, Cisco a mis a jour son billet de blogue initialement publié le 25 septembre 2025 (cf. section Documentation). L'éditeur déclare avoir connaissance d'une nouvelle attaque, affectant les équipements ASA et FTD vulnérables, qui cause un déni...
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-013/
# Date : Thu, 25 Sep 2025 00:00:00 +0000
# Titre : [MàJ] Vulnérabilité dans React Server Components (05 décembre 2025)
# Description: **[Mise à jour du 11 décembre 2025]** Le CERT-FR a connaissance de multiples exploitations de la vulnérabilité CVE-2025-55182. Les serveurs avec une version vulnérable exposés après la publication des preuves de concept publiques du 5 décembre 2025 doivent être considérés comme compromis....
# Lien : https://www.cert.ssi.gouv.fr/alerte/CERTFR-2025-ALE-014/
# Date : Fri, 05 Dec 2025 00:00:00 +0000

# %%
url2 = "https://cert.ssi.gouv.fr/avis/feed/"
rss_avis_feed = feedparser.parse(url2)
for entry in rss_avis_feed.entries:
 print("Titre :", entry.title)
 print("Description:", entry.description)
 print("Lien :", entry.link)
 print("Date :", entry.published)
# Out:
# Titre : Multiples vulnérabilités dans MISP (08 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans MISP. Elles permettent à un attaquant de provoquer une injection de code indirecte à distance (XSS).
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1076/
# Date : Mon, 08 Dec 2025 00:00:00 +0000
# Titre : Vulnérabilité dans les produits Mitel (11 décembre 2025)
# Description: Une vulnérabilité a été découverte dans les produits Mitel. Elle permet à un attaquant de provoquer une injection de code indirecte à distance (XSS).
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1097/
# Date : Thu, 11 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Roundcube (15 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans Roundcube. Elles permettent à un attaquant de provoquer une atteinte à la confidentialité des données et une injection de code indirecte à distance (XSS).
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1111/
# Date : Mon, 15 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Moodle (16 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans Moodle. Elles permettent à un attaquant de provoquer une atteinte à la confidentialité des données, une injection de code indirecte à distance (XSS) et un contournement de la politique de sécurité.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1113/
# Date : Tue, 16 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Tenable Nessus (16 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans Tenable Nessus. Elles permettent à un attaquant de provoquer un déni de service à distance et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1114/
# Date : Tue, 16 Dec 2025 00:00:00 +0000
# Titre : Vulnérabilité dans Trend Micro Apex One (16 décembre 2025)
# Description: Une vulnérabilité a été découverte dans Trend Micro Apex One. Elle permet à un attaquant de provoquer une exécution de code arbitraire.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1115/
# Date : Tue, 16 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Google Chrome (17 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans Google Chrome. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1116/
# Date : Wed, 17 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans GLPI (17 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans GLPI. Elles permettent à un attaquant de provoquer une injection de code indirecte à distance (XSS) et un contournement de la politique de sécurité.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1117/
# Date : Wed, 17 Dec 2025 00:00:00 +0000
# Titre : Vulnérabilité dans Mozilla Firefox (17 décembre 2025)
# Description: Une vulnérabilité a été découverte dans Mozilla Firefox. Elle permet à un attaquant de provoquer un contournement de la politique de sécurité.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1118/
# Date : Wed, 17 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Synology (17 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Synology. Elles permettent à un attaquant de provoquer une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1119/
# Date : Wed, 17 Dec 2025 00:00:00 +0000
# Titre : Vulnérabilité dans les produits Cisco (18 décembre 2025)
# Description: Une vulnérabilité a été découverte dans les produits Cisco. Elle permet à un attaquant de provoquer une exécution de code arbitraire à distance avec les droits administrateurs. Cisco indique que cette vulnérabilité est activement exploitée et fournit des recommandations dans son bulletin de...
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1120/
# Date : Thu, 18 Dec 2025 00:00:00 +0000
# Titre : Vulnérabilité dans Sonicwall Secure Mobile Access (18 décembre 2025)
# Description: Une vulnérabilité a été découverte dans Sonicwall Secure Mobile Access. Elle permet à un attaquant de provoquer une élévation de privilèges. Sonicwall indique que cette vulnérabilité est exploitée conjointement avec la vulnérabilité CVE-2025-23006 qui permet une exécution de code arbitraire à...
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1121/
# Date : Thu, 18 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Mattermost Server (18 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans Mattermost Server. Elles permettent à un attaquant de provoquer des problèmes de sécurité non spécifiés par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1122/
# Date : Thu, 18 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Elastic (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Elastic. Certaines d'entre elles permettent à un attaquant de provoquer un déni de service à distance, une atteinte à la confidentialité des données et une injection de code indirecte à distance (XSS).
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1123/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Microsoft Edge (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans Microsoft Edge. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1124/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Vulnérabilité dans les produits NetApp (19 décembre 2025)
# Description: Une vulnérabilité a été découverte dans les produits NetApp. Elle permet à un attaquant de provoquer une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1125/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Centreon Web (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans Centreon Web. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1127/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Mozilla Firefox (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans Mozilla Firefox. Elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance et un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1128/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits VMware (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans les produits VMware. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1129/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Foxit (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Foxit. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire, une élévation de privilèges et un déni de service.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1130/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits IBM (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans les produits IBM. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une élévation de privilèges et un déni de service à distance.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1131/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux de Red Hat (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux de Red Hat. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire, un déni de service à distance et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1132/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux de SUSE (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux de SUSE. Certaines d'entre elles permettent à un attaquant de provoquer une atteinte à la confidentialité des données, une atteinte à l'intégrité des données et un contournement de la politique de sécurité.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1133/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans MongoDB Server (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans MongoDB Server. Certaines d'entre elles permettent à un attaquant de provoquer un déni de service à distance, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1134/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux d'Ubuntu (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux d'Ubuntu. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1135/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux de Debian LTS (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux de Debian LTS. Certaines d'entre elles permettent à un attaquant de provoquer une élévation de privilèges, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1136/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans PHP (19 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans PHP. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1126/
# Date : Fri, 19 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits IBM (26 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans les produits IBM. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, un déni de service à distance et une atteinte à la confidentialité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1137/
# Date : Fri, 26 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans VMware Tanzu Platform (26 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans VMware Tanzu Platform. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1138/
# Date : Fri, 26 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux d'Ubuntu (26 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux d'Ubuntu. Elles permettent à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1139/
# Date : Fri, 26 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux de SUSE (26 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux de SUSE. Certaines d'entre elles permettent à un attaquant de provoquer une atteinte à la confidentialité des données, un contournement de la politique de sécurité et un déni de service.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1140/
# Date : Fri, 26 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux de Red Hat (26 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux de Red Hat. Elles permettent à un attaquant de provoquer un contournement de la politique de sécurité, un déni de service et un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1141/
# Date : Fri, 26 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Moxa NPort (31 décembre 2025)
# Description: De multiples vulnérabilités ont été découvertes dans Moxa NPort. Certaines d'entre elles permettent à un attaquant de provoquer une élévation de privilèges, un déni de service à distance et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2025-AVI-1142/
# Date : Wed, 31 Dec 2025 00:00:00 +0000
# Titre : Multiples vulnérabilités dans le noyau Linux de SUSE (02 janvier 2026)
# Description: De multiples vulnérabilités ont été découvertes dans le noyau Linux de SUSE. Elles permettent à un attaquant de provoquer une atteinte à l'intégrité des données et un déni de service.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0001/
# Date : Fri, 02 Jan 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits IBM (02 janvier 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits IBM. Certaines d'entre elles permettent à un attaquant de provoquer un déni de service à distance, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0002/
# Date : Fri, 02 Jan 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans les produits Qnap (05 janvier 2026)
# Description: De multiples vulnérabilités ont été découvertes dans les produits Qnap. Certaines d'entre elles permettent à un attaquant de provoquer un déni de service à distance, une atteinte à la confidentialité des données et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0003/
# Date : Mon, 05 Jan 2026 00:00:00 +0000
# Titre : Vulnérabilité dans MariaDB (05 janvier 2026)
# Description: Une vulnérabilité a été découverte dans MariaDB. Elle permet à un attaquant de provoquer un problème de sécurité non spécifié par l'éditeur.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0004/
# Date : Mon, 05 Jan 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Centreon Open Tickets (06 janvier 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Centreon Open Tickets. Elles permettent à un attaquant de provoquer une injection SQL (SQLi) et une injection de code indirecte à distance (XSS).
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0005/
# Date : Tue, 06 Jan 2026 00:00:00 +0000
# Titre : Multiples vulnérabilités dans Veeam Backup & Replication (06 janvier 2026)
# Description: De multiples vulnérabilités ont été découvertes dans Veeam Backup & Replication. Certaines d'entre elles permettent à un attaquant de provoquer une exécution de code arbitraire à distance, une élévation de privilèges et une atteinte à l'intégrité des données.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0006/
# Date : Tue, 06 Jan 2026 00:00:00 +0000
# Titre : Vulnérabilité dans Stormshield Network Security (06 janvier 2026)
# Description: Une vulnérabilité a été découverte dans Stormshield Network Security. Elle permet à un attaquant de provoquer une exécution de code arbitraire à distance et un déni de service à distance.
# Lien : https://www.cert.ssi.gouv.fr/avis/CERTFR-2026-AVI-0007/
# Date : Tue, 06 Jan 2026 00:00:00 +0000

# %%
for entry in rss_alertes_feed.entries:
    url = entry.link+"json/"
    response = requests.get(url)
    data = response.json()
    #Extraction des CVE reference dans la clé cves du dict data
    ref_cves=list(data["cves"])
    #attention il s’agit d’une liste des dictionnaires avec name et url comme clés
    print( "CVE référencés ", ref_cves)
    # Extraction des CVE avec une regex
    cve_pattern = r"CVE-\d{4}-\d{4,7}"
    cve_list_alertes = list(set(re.findall(cve_pattern, str(data))))
    print("CVE trouvés :", cve_list_alertes)
# Out:
# CVE référencés  [{'name': 'CVE-2022-40242', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-40242'}, {'name': 'CVE-2022-40259', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-40259'}, {'name': 'CVE-2022-2827', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-2827'}]
# CVE trouvés : ['CVE-2022-40242', 'CVE-2022-40259', 'CVE-2022-2827']
# CVE référencés  [{'name': 'CVE-2023-27997', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-27997'}]
# CVE trouvés : ['CVE-2023-27997']
# CVE référencés  [{'name': 'CVE-2023-34362', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-34362'}, {'name': 'CVE-2023-35036', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-35036'}, {'name': 'CVE-2023-35708', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-35708'}]
# CVE trouvés : ['CVE-2023-34362', 'CVE-2023-35708', 'CVE-2023-35036']
# CVE référencés  [{'name': 'CVE-2023-36884', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-36884'}]
# CVE trouvés : ['CVE-2023-36884']
# CVE référencés  [{'name': 'CVE-2023-37580', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-37580'}]
# CVE trouvés : ['CVE-2023-37580']
# CVE référencés  [{'name': 'CVE-2023-3519', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-3519'}]
# CVE trouvés : ['CVE-2023-3519']
# CVE référencés  [{'name': 'CVE-2023-35081', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-35081'}, {'name': 'CVE-2023-35082', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-35082'}, {'name': 'CVE-2023-35078', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-35078'}]
# CVE trouvés : ['CVE-2023-35081', 'CVE-2023-35082', 'CVE-2023-35078']
# CVE référencés  [{'name': 'CVE-2023-42118', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-42118'}, {'name': 'CVE-2023-42116', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-42116'}, {'name': 'CVE-2023-42115', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-42115'}, {'name': 'CVE-2023-42117', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-42117'}, {'name': 'CVE-2023-42119', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-42119'}, {'name': 'CVE-2023-42114', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-42114'}]
# CVE trouvés : ['CVE-2023-42115', 'CVE-2023-42114', 'CVE-2023-42118', 'CVE-2023-42119', 'CVE-2023-42116', 'CVE-2023-42117']
# CVE référencés  [{'name': 'CVE-2023-20198', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-20198'}, {'name': 'CVE-2023-20273', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-20273'}]
# CVE trouvés : ['CVE-2023-20198', 'CVE-2023-20273']
# CVE référencés  [{'name': 'CVE-2023-4966', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-4966'}]
# CVE trouvés : ['CVE-2023-4966']
# CVE référencés  [{'name': 'CVE-2023-50164', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-50164'}]
# CVE trouvés : ['CVE-2023-50164']
# CVE référencés  [{'name': 'CVE-2023-46805', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-46805'}, {'name': 'CVE-2024-21887', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-21887'}, {'name': 'CVE-2024-21893', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-21893'}, {'name': 'CVE-2024-21888', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-21888'}, {'name': 'CVE-2024-22024', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-22024'}]
# CVE trouvés : ['CVE-2024-21887', 'CVE-2024-22024', 'CVE-2024-21888', 'CVE-2023-46805', 'CVE-2024-21893']
# CVE référencés  [{'name': 'CVE-2024-0402', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-0402'}, {'name': 'CVE-2023-7028', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-7028'}]
# CVE trouvés : ['CVE-2024-0402', 'CVE-2023-7028']
# CVE référencés  []
# CVE trouvés : []
# CVE référencés  [{'name': 'CVE-2024-21762', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-21762'}]
# CVE trouvés : ['CVE-2024-21762']
# CVE référencés  [{'name': 'CVE-2024-21413', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-21413'}]
# CVE trouvés : ['CVE-2024-21413']
# CVE référencés  [{'name': 'CVE-2024-3400', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-3400'}]
# CVE trouvés : ['CVE-2024-3400']
# CVE référencés  [{'name': 'CVE-2024-20353', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-20353'}, {'name': 'CVE-2024-20359', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-20359'}]
# CVE trouvés : ['CVE-2024-20359', 'CVE-2024-20353']
# CVE référencés  [{'name': 'CVE-2024-24919', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-24919'}]
# CVE trouvés : ['CVE-2024-24919']
# CVE référencés  [{'name': 'CVE-2024-6387', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-6387'}]
# CVE trouvés : ['CVE-2024-6387']
# CVE référencés  [{'name': 'CVE-2024-42008', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-42008'}, {'name': 'CVE-2024-42009', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-42009'}, {'name': 'CVE-2024-42010', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-42010'}]
# CVE trouvés : ['CVE-2024-42010', 'CVE-2024-42009', 'CVE-2024-42008']
# CVE référencés  [{'name': 'CVE-2024-40766', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-40766'}]
# CVE trouvés : ['CVE-2024-40766']
# CVE référencés  [{'name': 'CVE-2024-47176', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-47176'}, {'name': 'CVE-2024-47076', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-47076'}, {'name': 'CVE-2024-47175', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-47175'}, {'name': 'CVE-2024-47177', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-47177'}]
# CVE trouvés : ['CVE-2024-47177', 'CVE-2024-47176', 'CVE-2024-47076', 'CVE-2024-47175']
# CVE référencés  [{'name': 'CVE-2024-8190', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-8190'}, {'name': 'CVE-2024-8963', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-8963'}, {'name': 'CVE-2024-9380', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-9380'}]
# CVE trouvés : ['CVE-2024-8190', 'CVE-2024-8963', 'CVE-2024-9379', 'CVE-2024-9380', 'CVE-2024-9381']
# CVE référencés  [{'name': 'CVE-2024-47575', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-47575'}, {'name': 'CVE-2024-50566', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-50566'}]
# CVE trouvés : ['CVE-2024-50566', 'CVE-2024-47575']
# CVE référencés  [{'name': 'CVE-2024-0012', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-0012'}, {'name': 'CVE-2024-9474', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-9474'}]
# CVE trouvés : ['CVE-2024-9474', 'CVE-2024-0012']
# CVE référencés  [{'name': 'CVE-2025-0282', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-0282'}]
# CVE trouvés : ['CVE-2025-0282', 'CVE-2025-0283']
# CVE référencés  [{'name': 'CVE-2024-55591', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-55591'}]
# CVE trouvés : ['CVE-2024-55591']
# CVE référencés  [{'name': 'CVE-2025-22457', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-22457'}]
# CVE trouvés : ['CVE-2025-0282', 'CVE-2025-22457']
# CVE référencés  []
# CVE trouvés : ['CVE-2022-42475', 'CVE-2024-21762', 'CVE-2023-27997']
# CVE référencés  [{'name': 'CVE-2025-31324', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-31324'}]
# CVE trouvés : ['CVE-2025-31324']
# CVE référencés  [{'name': 'CVE-2025-32756', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-32756'}]
# CVE trouvés : ['CVE-2025-32756']
# CVE référencés  [{'name': 'CVE-2025-4427', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-4427'}, {'name': 'CVE-2025-4428', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-4428'}]
# CVE trouvés : ['CVE-2025-4427', 'CVE-2025-4428']
# CVE référencés  [{'name': 'CVE-2025-49113', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-49113'}]
# CVE trouvés : ['CVE-2025-49113']
# CVE référencés  [{'name': 'CVE-2025-6543', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-6543'}, {'name': 'CVE-2025-5777', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-5777'}]
# CVE trouvés : ['CVE-2025-6543', 'CVE-2025-5777']
# CVE référencés  [{'name': 'CVE-2025-53770', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-53770'}, {'name': 'CVE-2025-53771', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-53771'}]
# CVE trouvés : ['CVE-2025-53770', 'CVE-2025-53771']
# CVE référencés  []
# CVE trouvés : ['CVE-2024-40766']
# CVE référencés  [{'name': 'CVE-2025-7775', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-7775'}]
# CVE trouvés : ['CVE-2025-7775']
# CVE référencés  [{'name': 'CVE-2025-20333', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-20333'}, {'name': 'CVE-2025-20362', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-20362'}]
# CVE trouvés : ['CVE-2025-20362', 'CVE-2025-20333']
# CVE référencés  [{'name': 'CVE-2025-55182', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-55182'}, {'name': 'CVE-2025-66478', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-66478'}]
# CVE trouvés : ['CVE-2025-55182', 'CVE-2025-66478']

# %%
for entry in rss_avis_feed.entries:
    url = entry.link+"json/"
    response = requests.get(url)
    data = response.json()
    #Extraction des CVE reference dans la clé cves du dict data
    ref_cves=list(data["cves"])
    #attention il s’agit d’une liste des dictionnaires avec name et url comme clés
    print( "CVE référencés ", ref_cves)
    # Extraction des CVE avec une regex
    cve_pattern = r"CVE-\d{4}-\d{4,7}"
    cve_list_avis = list(set(re.findall(cve_pattern, str(data))))
    print("CVE trouvés :", cve_list_avis)
# Out:
# CVE référencés  [{'name': 'CVE-2025-67906', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67906'}]
# CVE trouvés : ['CVE-2025-67906']
# CVE référencés  [{'name': 'CVE-2025-67823', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67823'}]
# CVE trouvés : ['CVE-2025-67823']
# CVE référencés  [{'name': 'CVE-2025-68460', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68460'}, {'name': 'CVE-2025-68461', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68461'}]
# CVE trouvés : ['CVE-2025-68461', 'CVE-2025-68460']
# CVE référencés  [{'name': 'CVE-2025-67848', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67848'}, {'name': 'CVE-2025-67852', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67852'}, {'name': 'CVE-2025-67850', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67850'}, {'name': 'CVE-2025-67849', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67849'}, {'name': 'CVE-2025-67851', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67851'}, {'name': 'CVE-2025-67853', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67853'}, {'name': 'CVE-2025-67856', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67856'}, {'name': 'CVE-2025-67855', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67855'}, {'name': 'CVE-2025-67854', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67854'}, {'name': 'CVE-2025-67857', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-67857'}]
# CVE trouvés : ['CVE-2025-67848', 'CVE-2025-67851', 'CVE-2025-67852', 'CVE-2025-67849', 'CVE-2025-67855', 'CVE-2025-67850', 'CVE-2025-67853', 'CVE-2025-67856', 'CVE-2025-67857', 'CVE-2025-67854']
# CVE référencés  [{'name': 'CVE-2025-11731', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-11731'}, {'name': 'CVE-2025-49794', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-49794'}, {'name': 'CVE-2024-8176', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-8176'}, {'name': 'CVE-2025-59375', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-59375'}, {'name': 'CVE-2025-7425', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-7425'}, {'name': 'CVE-2025-6170', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-6170'}, {'name': 'CVE-2025-10911', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-10911'}, {'name': 'CVE-2024-55549', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-55549'}, {'name': 'CVE-2025-6021', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-6021'}, {'name': 'CVE-2025-49796', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-49796'}]
# CVE trouvés : ['CVE-2024-8176', 'CVE-2025-6170', 'CVE-2025-59375', 'CVE-2025-6021', 'CVE-2024-55549', 'CVE-2025-49794', 'CVE-2025-10911', 'CVE-2025-49796', 'CVE-2025-7425', 'CVE-2025-11731']
# CVE référencés  [{'name': 'CVE-2025-49844', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-49844'}]
# CVE trouvés : ['CVE-2025-49844']
# CVE référencés  [{'name': 'CVE-2025-14766', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-14766'}, {'name': 'CVE-2025-14765', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-14765'}]
# CVE trouvés : ['CVE-2025-14765', 'CVE-2025-14766']
# CVE référencés  [{'name': 'CVE-2025-59935', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-59935'}, {'name': 'CVE-2025-64520', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-64520'}]
# CVE trouvés : ['CVE-2025-64520', 'CVE-2025-59935']
# CVE référencés  [{'name': 'CVE-2025-14744', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-14744'}]
# CVE trouvés : ['CVE-2025-14744']
# CVE référencés  [{'name': 'CVE-2025-14713', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-14713'}, {'name': 'CVE-2025-66593', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-66593'}, {'name': 'CVE-2025-66592', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-66592'}]
# CVE trouvés : ['CVE-2025-66593', 'CVE-2025-66592', 'CVE-2025-14713']
# CVE référencés  [{'name': 'CVE-2025-20393', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-20393'}]
# CVE trouvés : ['CVE-2025-20393']
# CVE référencés  [{'name': 'CVE-2025-40602', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40602'}]
# CVE trouvés : ['CVE-2025-23006', 'CVE-2025-40602']
# CVE référencés  [{'name': 'CVE-2025-12689', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-12689'}, {'name': 'CVE-2025-14273', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-14273'}]
# CVE trouvés : ['CVE-2025-12689', 'CVE-2025-14273']
# CVE référencés  [{'name': 'CVE-2025-68384', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68384'}, {'name': 'CVE-2025-68381', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68381'}, {'name': 'CVE-2025-68385', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68385'}, {'name': 'CVE-2025-68389', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68389'}, {'name': 'CVE-2025-68387', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68387'}, {'name': 'CVE-2025-68422', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68422'}, {'name': 'CVE-2025-68382', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68382'}, {'name': 'CVE-2025-68388', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68388'}, {'name': 'CVE-2025-68390', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68390'}, {'name': 'CVE-2025-68386', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68386'}, {'name': 'CVE-2025-68383', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-68383'}]
# CVE trouvés : ['CVE-2025-68381', 'CVE-2025-68422', 'CVE-2025-68390', 'CVE-2025-68386', 'CVE-2025-68389', 'CVE-2025-68388', 'CVE-2025-68384', 'CVE-2025-68383', 'CVE-2025-68385', 'CVE-2025-68382', 'CVE-2025-68387']
# CVE référencés  [{'name': 'CVE-2025-14766', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-14766'}, {'name': 'CVE-2025-14765', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-14765'}, {'name': 'CVE-2025-65046', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-65046'}]
# CVE trouvés : ['CVE-2025-65046', 'CVE-2025-14765', 'CVE-2025-14766']
# CVE référencés  [{'name': 'CVE-2007-2768', 'url': 'https://www.cve.org/CVERecord?id=CVE-2007-2768'}]
# CVE trouvés : ['CVE-2007-2768']
# CVE référencés  [{'name': 'CVE-2025-43864', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-43864'}, {'name': 'CVE-2025-43865', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-43865'}]
# CVE trouvés : ['CVE-2025-43864', 'CVE-2025-43865']
# CVE référencés  [{'name': 'CVE-2025-14861', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-14861'}, {'name': 'CVE-2025-14860', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-14860'}]
# CVE trouvés : ['CVE-2025-14860', 'CVE-2025-14861']
# CVE référencés  [{'name': 'CVE-2025-58183', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-58183'}, {'name': 'CVE-2025-59830', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-59830'}, {'name': 'CVE-2025-12816', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-12816'}, {'name': 'CVE-2025-25186', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-25186'}, {'name': 'CVE-2025-22872', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-22872'}, {'name': 'CVE-2024-25126', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-25126'}, {'name': 'CVE-2025-0913', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-0913'}, {'name': 'CVE-2025-47907', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-47907'}, {'name': 'CVE-2025-27219', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-27219'}, {'name': 'CVE-2025-3573', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-3573'}, {'name': 'CVE-2023-45288', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-45288'}, {'name': 'CVE-2025-58185', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-58185'}, {'name': 'CVE-2024-45341', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-45341'}, {'name': 'CVE-2025-61919', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-61919'}, {'name': 'CVE-2025-61771', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-61771'}, {'name': 'CVE-2025-61770', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-61770'}, {'name': 'CVE-2025-64329', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-64329'}, {'name': 'CVE-2025-8291', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-8291'}, {'name': 'CVE-2025-61727', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-61727'}, {'name': 'CVE-2025-22866', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-22866'}, {'name': 'CVE-2024-34158', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-34158'}, {'name': 'CVE-2025-27111', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-27111'}, {'name': 'CVE-2025-66031', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-66031'}, {'name': 'CVE-2025-47910', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-47910'}, {'name': 'CVE-2025-46727', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-46727'}, {'name': 'CVE-2023-48795', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-48795'}, {'name': 'CVE-2025-47906', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-47906'}, {'name': 'CVE-2025-31133', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-31133'}, {'name': 'CVE-2024-3044', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-3044'}, {'name': 'CVE-2025-58188', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-58188'}, {'name': 'CVE-2020-7792', 'url': 'https://www.cve.org/CVERecord?id=CVE-2020-7792'}, {'name': 'CVE-2025-4674', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-4674'}, {'name': 'CVE-2022-29526', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-29526'}, {'name': 'CVE-2024-21538', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-21538'}, {'name': 'CVE-2024-45336', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-45336'}, {'name': 'CVE-2025-52881', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-52881'}, {'name': 'CVE-2025-61724', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-61724'}, {'name': 'CVE-2025-61723', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-61723'}, {'name': 'CVE-2025-61795', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-61795'}, {'name': 'CVE-2024-26146', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-26146'}, {'name': 'CVE-2024-45337', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024
 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-3510'}, {'name': 'CVE-2022-3509', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-3509'}, {'name': 'CVE-2023-22067', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-22067'}, {'name': 'CVE-2025-55173', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-55173'}, {'name': 'CVE-2025-48068', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-48068'}, {'name': 'CVE-2025-7783', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-7783'}, {'name': 'CVE-2025-55182', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-55182'}, {'name': 'CVE-2025-57752', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-57752'}, {'name': 'CVE-2015-8388', 'url': 'https://www.cve.org/CVERecord?id=CVE-2015-8388'}, {'name': 'CVE-2018-25032', 'url': 'https://www.cve.org/CVERecord?id=CVE-2018-25032'}, {'name': 'CVE-2023-40692', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-40692'}, {'name': 'CVE-2023-38003', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-38003'}, {'name': 'CVE-2025-21587', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-21587'}, {'name': 'CVE-2022-37434', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-37434'}, {'name': 'CVE-2024-35195', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-35195'}, {'name': 'CVE-2025-9288', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-9288'}, {'name': 'CVE-2023-33850', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-33850'}, {'name': 'CVE-2015-8385', 'url': 'https://www.cve.org/CVERecord?id=CVE-2015-8385'}, {'name': 'CVE-2015-8394', 'url': 'https://www.cve.org/CVERecord?id=CVE-2015-8394'}, {'name': 'CVE-2015-8391', 'url': 'https://www.cve.org/CVERecord?id=CVE-2015-8391'}, {'name': 'CVE-2015-8386', 'url': 'https://www.cve.org/CVERe ...
# ...
# CVE référencés  [{'name': 'CVE-2022-49390', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-49390'}, {'name': 'CVE-2025-37958', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-37958'}, {'name': 'CVE-2025-21855', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-21855'}, {'name': 'CVE-2025-38666', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-38666'}, {'name': 'CVE-2024-50196', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-50196'}, {'name': 'CVE-2024-50095', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-50095'}, {'name': 'CVE-2022-49026', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-49026'}, {'name': 'CVE-2025-39964', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-39964'}, {'name': 'CVE-2025-39993', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-39993'}, {'name': 'CVE-2024-49935', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-49935'}, {'name': 'CVE-2025-40018', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40018'}, {'name': 'CVE-2024-53218', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-53218'}, {'name': 'CVE-2024-53090', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-53090'}, {'name': 'CVE-2024-50067', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-50067'}, {'name': 'CVE-2025-39946', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-39946'}, {'name': 'CVE-2024-47691', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-47691'}]
# CVE trouvés : ['CVE-2022-49026', 'CVE-2025-39964', 'CVE-2024-47691', 'CVE-2025-38666', 'CVE-2025-37958', 'CVE-2025-39946', 'CVE-2025-39993', 'CVE-2024-53090', 'CVE-2024-53218', 'CVE-2022-49390', 'CVE-2025-21855', 'CVE-2024-50095', 'CVE-2024-50196', 'CVE-2025-40018', 'CVE-2024-49935', 'CVE-2024-50067']
# CVE référencés  [{'name': 'CVE-2025-40064', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40064'}, {'name': 'CVE-2025-40156', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40156'}, {'name': 'CVE-2025-40055', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40055'}, {'name': 'CVE-2025-40048', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40048'}, {'name': 'CVE-2025-40121', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40121'}, {'name': 'CVE-2025-40204', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40204'}, {'name': 'CVE-2025-40171', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40171'}, {'name': 'CVE-2022-50368', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-50368'}, {'name': 'CVE-2025-40139', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40139'}, {'name': 'CVE-2025-39967', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-39967'}, {'name': 'CVE-2025-40107', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40107'}, {'name': 'CVE-2025-40115', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40115'}, {'name': 'CVE-2025-40198', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-
E-2024-53093', 'CVE-2025-40194', 'CVE-2022-50280', 'CVE-2025-40141', 'CVE-2023-53641', 'CVE-2025-40086', 'CVE-2022-50545', 'CVE-2025-40048', 'CVE-2025-40188', 'CVE-2022-50364', 'CVE-2025-40180', 'CVE-2025-21710', 'CVE-2025-40027', 'CVE-2023-53597', 'CVE-2025-40156', 'CVE-2025-40207', 'CVE-2025-40154', 'CVE-2025-40059', 'CVE-2025-39944', 'CVE-2025-40139', 'CVE-2025-40080', 'CVE-2025-38361', 'CVE-2025-38360', 'CVE-2023-53676', 'CVE-2025-40110']
# CVE référencés  [{'name': 'CVE-2022-50356', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-50356'}, {'name': 'CVE-2022-50367', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-50367'}, {'name': 'CVE-2025-39757', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-39757'}, {'name': 'CVE-2025-39925', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-39925'}, {'name': 'CVE-2025-39843', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-39843'}, {'name': 'CVE-2022-50406', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-50406'}, {'name': 'CVE-2023-53322', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-53322'}, {'name': 'CVE-2023-53178', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-53178'}, {'name': 'CVE-2025-38729', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-38729'}, {'name': 'CVE-2025-39955', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-39955'}, {'name': 'CVE-2022-50403', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-50403'}, {'name': 'CVE-2023-53297', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-53297'}, {'name': 'CVE-2022-50410', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-50410'}]
# CVE trouvés : ['CVE-2022-50406', 'CVE-2022-50410', 'CVE-2023-53178', 'CVE-2025-39955', 'CVE-2025-39843', 'CVE-2022-50356', 'CVE-2023-53322', 'CVE-2022-50367', 'CVE-2025-38729', 'CVE-2022-50403', 'CVE-2025-39925', 'CVE-2023-53297', 'CVE-2025-39757']
# CVE référencés  [{'name': 'CVE-2025-1977', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-1977'}, {'name': 'CVE-2025-15017', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-15017'}, {'name': 'CVE-2025-2026', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-2026'}]
# CVE trouvés : ['CVE-2025-15017', 'CVE-2025-2026', 'CVE-2025-1977']
# CVE référencés  [{'name': 'CVE-2025-40121', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40121'}, {'name': 'CVE-2025-40204', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40204'}, {'name': 'CVE-2023-53659', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-53659'}, {'name': 'CVE-2022-50280', 'url': 'https://www.cve.org/CVERecord?id=CVE-2022-50280'}, {'name': 'CVE-2025-40040', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40040'}, {'name': 'CVE-2023-53717', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-53717'}, {'name': 'CVE-2025-40154', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-40154'}, {'name': 'CVE-2023-53676', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-53676'}]
# CVE trouvés : ['CVE-2025-40154', 'CVE-2025-40040', 'CVE-2025-40204', 'CVE-2023-53717', 'CVE-2022-50280', 'CVE-2023-53659', 'CVE-2025-40121', 'CVE-2023-53676']
# CVE référencés  [{'name': 'CVE-2025-48795', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-48795'}, {'name': 'CVE-2020-36732', 'url': 'https://www.cve.org/CVERecord?id=CVE-2020-36732'}, {'name': 'CVE-2025-36047', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-36047'}, {'name': 'CVE-2023-48795', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-48795'}, {'name': 'CVE-2024-47554', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-47554'}, {'name': 'CVE-2025-48976', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-48976'}, {'name': 'CVE-2023-6378', 'url': 'https://www.cve.org/CVERecord?id=CVE-2023-6378'}, {'name': 'CVE-2024-56339', 'url': 'https://www.cve.org/CVERecord?id=CVE-2024-56339'}, {'name': 'CVE-2025-36000', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-36000'}, {'name': 'CVE-2025-36124', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025
 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-8460'}]
# CVE trouvés : ['CVE-2025-54890', 'CVE-2025-12514', 'CVE-2025-8460']
# CVE référencés  [{'name': 'CVE-2025-59470', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-59470'}, {'name': 'CVE-2025-59468', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-59468'}, {'name': 'CVE-2025-59469', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-59469'}, {'name': 'CVE-2025-55125', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-55125'}]
# CVE trouvés : ['CVE-2025-59469', 'CVE-2025-55125', 'CVE-2025-59470', 'CVE-2025-59468']
# CVE référencés  [{'name': 'CVE-2025-31115', 'url': 'https://www.cve.org/CVERecord?id=CVE-2025-31115'}]
# CVE trouvés : ['CVE-2025-31115']

# %%
#l'API CVE :
import requests
for cve_id in cve_list_avis :

    url = f"https://cveawg.mitre.org/api/cve/{cve_id}"
    response = requests.get(url)
    data = response.json()
    # Extraire la description
    description = data["containers"]["cna"]["descriptions"][0]["value"]
    # Extraire le score CVSS
    #ATTENTION tous les CVE ne contiennent pas nécessairement ce champ, gérez l’exception,
    #ou peut etre au lieu de cvssV3_0 c’est cvssV3_1 ou autre clé
    #cvss_score =data["containers"]["cna"]["metrics"][0]["cvssV3_0"]["baseScore"]
    print(data["containers"]["cna"]["metrics"][0])
    '''
    cwe = "Non disponible"
    cwe_desc="Non disponible"
    problemtype = data["containers"]["cna"].get("problemTypes", {})
    if problemtype and "descriptions" in problemtype[0]:
     cwe = problemtype[0]["descriptions"][0].get("cweId", "Non disponible")
     cwe_desc=problemtype[0]["descriptions"][0].get("description", "Non disponible")
    # Extraire les produits affectés
    affected = data["containers"]["cna"]["affected"]
    for product in affected:
     vendor = product["vendor"]
     product_name = product["product"]
     versions = [v["version"] for v in product["versions"] if v["status"] == "affected"]
     print(f"Éditeur : {vendor}, Produit : {product_name}, Versions : {', '.join(versions)}")
    # Afficher les résultats
    print(f"CVE : {cve_id}")
    print(f"Description : {description}")
    print(f"Score CVSS : {cvss_score}")
    print(f"Type CWE : {cwe}")
    print(f"CWE Description : {cwe_desc}")
    '''
# Out:
# {'cvssV4_0': {'attackVector': 'NETWORK', 'attackComplexity': 'LOW', 'attackRequirements': 'NONE', 'privilegesRequired': 'NONE', 'userInteraction': 'NONE', 'vulnConfidentialityImpact': 'NONE', 'vulnIntegrityImpact': 'NONE', 'vulnAvailabilityImpact': 'HIGH', 'subConfidentialityImpact': 'NONE', 'subIntegrityImpact': 'NONE', 'subAvailabilityImpact': 'NONE', 'baseScore': 8.7, 'baseSeverity': 'HIGH', 'vectorString': 'CVSS:4.0/AV:N/AC:L/AT:N/PR:N/UI:N/VC:N/VI:N/VA:H/SC:N/SI:N/SA:N', 'version': '4.0'}}

# %%
#l’API EPSS:
import requests
# URL de l'API EPSS pour récupérer la probabilité d'exploitation
cve_id = "CVE-2023-46805"
url = f"https://api.first.org/data/v1/epss?cve={cve_id}"
# Requête GET pour récupérer les données JSON
response = requests.get(url)
data = response.json()
# Extraire le score EPSS
epss_data = data.get("data", [])
if epss_data:
 epss_score = epss_data[0]["epss"]
 print(f"CVE : {cve_id}")
 print(f"Score EPSS : {epss_score}")
else:
 print(f"Aucun score EPSS trouvé pour {cve_id}")
